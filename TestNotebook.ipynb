# %% [markdown]
# # Stemming Tutorial

# %% [markdown]
# 1 . Importing Packages

# %% [markdown]
# 2. Defining Sample Paragraph

# %% [markdown]
# 3. Word Tokenize the Paragraph

# %% [markdown]
# 4. Define the PorterStemmer object

# %% [markdown]
# 5. Perform the stemming operations
